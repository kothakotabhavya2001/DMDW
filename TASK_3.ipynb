# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random . randint(0,100,size=(3,4)),columns = list('ABCD'))
print(df)
np.sin(df*np.pi/4)
first_value = df.iloc[0][0]
print(df.subtract(first_value,axis = 1))
first_row = df.iloc[0]
print(df.subtract(first_value,axis = 1))
# Out:
#     A   B   C   D
# 0  52  92  34  97
# 1  32  22  59  23
# 2  78  58  30  62
#     A   B   C   D
# 0   0  40 -18  45
# 1 -20 -30   7 -29
# 2  26   6 -22  10
#     A   B   C   D
# 0   0  40 -18  45
# 1 -20 -30   7 -29
# 2  26   6 -22  10

# %%
import pandas as pd 
df=pd.read_csv ('Iris.csv')
print (df.head (8) )
print (df.tail (7) )
print (df. dtypes)
x = '/content/Iris.csv'
record=pd.read_csv(x)
print (record ['PetalLengthCm']. unique ())
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 143  144            6.8  ...           2.3  Iris-virginica
# 144  145            6.7  ...           2.5  Iris-virginica
# 145  146            6.7  ...           2.3  Iris-virginica
# ...

# %%
import pandas as pd 
df2 = pd.read_csv("Iris.csv") 
print (df2)
df2.std(axis=0,skipna=True)
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]
# Id               43.445368
# SepalLengthCm     0.828066
# SepalWidthCm      0.433594
# PetalLengthCm     1.764420
# PetalWidthCm      0.763161
# dtype: float64

# %%
df2.rename (columns={"SepalWidthCm": 'SEPAL WIDTH'})
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
import pandas as pd
df2= pd.read_csv("Iris.csv")
duplicate= df2 [df2. duplicated ()]
print ( duplicate)
df2.drop_duplicates(keep=False,inplace=True)
# Out:
# Empty DataFrame
# Columns: [Id, SepalLengthCm, SepalWidthCm, PetalLengthCm, PetalWidthCm, Species]
# Index: []

# %%
df2=pd .read_csv("Iris.csv")
df2 
gk=df2.groupby('SepalLengthCm')
gk. first ()
# Out:
#                 Id  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# SepalLengthCm
# 4.3             14           3.0            1.1           0.1      Iris-setosa
# 4.4              9           2.9            1.4           0.2      Iris-setosa
# 4.5             42           2.3            1.3           0.3      Iris-setosa
# 4.6              4           3.1            1.5           0.2      Iris-setosa
# 4.7              3           3.2            1.3           0.2      Iris-setosa
# 4.8             12           3.4            1.6           0.2      Iris-setosa
# 4.9              2           3.0            1.4           0.2      Iris-setosa
# 5.0              5           3.6            1.4           0.2      Iris-setosa
# 5.1              1           3.5            1.4           0.2      Iris-setosa
# 5.2             28           3.5            1.5           0.2      Iris-setosa
# 5.3             49           3.7            1.5           0.2      Iris-setosa
# ...
